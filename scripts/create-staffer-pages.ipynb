# %%
import os

def write_markdown_file(line):
    # Split the line by tab to get individual fields
    fields = line.strip().split('\t')
    
    # Extract information from fields
    timestamp, full_name, pronouns, _, description, hometown, askabout, food = fields
    first_name, last_name = full_name.split()
    food_emoji = food[0]
    food = food[2:]
    
    # Format the markdown content
    content = f"""---
name: {full_name}
role: Tutor
pronouns: {pronouns}
email: 
photo: assets/staff-images/sp24/{last_name.lower()}-{first_name.lower()}.jpg
description: {description}
hometown: {hometown}
askabout: {askabout}
foodemoji: {food_emoji} 
food: {food}
---"""
    
    path = "../_staffers/"

    # Define the file name
    file_name = f"{path}{last_name.lower()}-{first_name.lower()}.md"
    
    # Write the content to the file
    with open(file_name, 'w') as f:
        f.write(content)
    
    print(f"{file_name} has been written successfully!")

# %%
# Copy-paste the eight relevant columns from the staff onboarding form responses
all_lines = """9/19/2024 15:32:10	Aathi Muthu	he/him	https://drive.google.com/file/d/1Jta_xgahg1l4JvLQVaS9ME8fnARkjL-v/view?usp=sharing	2nd year, Data Science, Eighth	San Jose, CA	Gymnastics, movies/TV shows, traveling	🌮 Don Carlos Taco Shop, Madras Cafe, Haidilao Hotpot
9/19/2024 9:34:20	Ashley Ho	she/her	https://drive.google.com/file/d/1J1CjsEvzpwtIXh_9Qs13T-LgPu8vqxBJ/view?usp=drive_link	1st year, M.S. in Data Science	Irvine, CA	Cooking, movies/TV shows, corgis	🥪 Mendocino Farms, Formoosa, Ramen Nagi
9/22/2024 21:35:09	Athulith Paraselli	he/him	https://drive.google.com/file/d/1ZLEx-0pdfsjVfIbvNqkDL43Z93G3KuCj/view?usp=drivesdk	4th year, Math-CS, Marshall	San Diego, CA	Music, video games, Internships	🍟 Raising canes, CoCo Ichibanya, Charminar
9/22/2024 12:32:31	Bill Wang	he/him	https://drive.google.com/file/d/1SQNKL8hUxdpwIXB9cPNT6lqktqaWxhB8/view?usp=sharing	3rd year, Data Science, Seventh	Los Gatos, CA	Piano	🌶️ Spicy City, Taco Stand
9/20/2024 16:31:43	Charlie Gillet	he/him	https://drive.google.com/file/d/1DTmypev9YYWUnpocoHmfv1IoXYV9E2iS/view?usp=drive_link	4th year, Data Science, Seventh	Redwood City, CA	Running/hiking, dragon boat racing, basketball	🌮 Tacos El Gordo, Spicy House, PT Eatery
9/20/2024 18:55:41	Ciro Zhang	he/him	https://drive.google.com/file/d/1sw0lE791jZmE3fRRtuHlT9a8ibpZ2pWi/view?usp=sharing	3rd year, Data Science and Computer Engineering, ERC	Richmond, BC, Canada	Chess, badminton, cockatiels	🌮 Chipotle, Shake Shack, Mains Hot Chicken
9/19/2024 10:05:58	Claire Wang	she/her	https://drive.google.com/file/d/1wZ4u0cmXuRu_0hBRLYsTlsrttk-KGo2F/view?usp=sharing	2nd year, Data science, Seventh	San Jose, CA	Clarinet, reading, going to the beach	🍣 Kinoyume Sushi and Grill, Mendocino Farms
9/20/2024 0:37:03	Daniel Budidharma	he/him	https://drive.google.com/file/d/1xwsVBFTvo6KaiobE2BEn9KSWhhn9SXnS/view?usp=sharing	2nd year, Data Science, Sixth	Jakarta, Indonesia	Movies, hiking, video games, Hearts of Iron 4, anime/manga	🌶️ Spicy City, Jasmine, Tacos El Gordo, Phil's BBQ, The Fire Spot
9/19/2024 12:13:12	Dhruv Sehgal	he/him	https://drive.google.com/file/d/17EwLIyA9xByeJA_C6C8WDDvSSG09K-sg/view?usp=sharing	2nd year, Data Science, Seventh College	Gurugram, Haryana, India	Skateboarding, music, rubik's cubes, rabbitholes, paper airplanes	🍤 Oscars, Charminar, Haidilao Hotpot, Pinpoint Cafe
9/20/2024 21:43:04	Eric Chen	he/him	https://drive.google.com/file/d/1VcAgsnpBEIEFev2k3j1veITc4rWms4Jg/view?usp=sharing	4th year, Data Science, Marshall	Orange County, CA	Pop music, Survivor, food	🍚 Eastern Dynasty, Spicy House, Izakaya Sakura
9/19/2024 12:18:36	Francisco Franco 	he/him	https://drive.google.com/file/d/1b8m3p5FCeHMDM4RIcjWuR1kF0PdICzzL/view?usp=drive_link	2nd year, Data Science Major, Warren College 	Salinas, CA 	Tutoring for SPIS, ML and AI, the ACM club, gym, and boogie boarding	🌮 Tacos El Gordo, Caroline's Seaside Cafe by Giuseppe, Manna BBQ
9/19/2024 9:27:52	Hargen Zheng	he/him	https://drive.google.com/file/d/15_oMfo7QbNsFyTJaal0zxR_TgOZilwlk/view?usp=sharing	3rd Year, Data Science and Math-CS, Sixth	Hangzhou, Zhejiang, China	Research about Information Retrieval in Large Language Models, playing yo-yo, watching NBA	🥩 Rei Do Gado Brazilian Steakhouse, Makai
9/19/2024 9:56:37	Jack Determan	he/him	https://drive.google.com/file/d/1tEa2_-V4HhNu_TYwxwUQFg2AP-PXd2Um/view?usp=drive_link	3rd Year, Math-CS, ERC	North Andover, MA	Running, chess, piano, manim code, reading	🍍 Duke's La Jolla, Barbarella's, BJs
9/19/2024 11:12:41	Jason Huynh	he/him	https://drive.google.com/file/d/1_wrHK-odM3sSvpySyulZcAGyc0jVN1eE/view?usp=sharing	3rd year, Data Science, Sixth	Modesto, CA	Gym, life, music	🍕 Catania, Tacos El Gordo, Pho Cow Cali Express
9/19/2024 15:36:49	Kate Feng	she/her	https://drive.google.com/file/d/1j1t2dPwPL-AFVdFJJhJx9M1eNl2-xZHl/view?usp=sharing	2nd year, Data Science, Seventh	San Jose, CA	Taekwondo, marketing, ghibli	🥐 La Clochette, Don Carlos Taco Shop
9/19/2024 11:32:05	Kathleen Nguyen	she/her	https://drive.google.com/file/d/1SaO7j_5wPSYHVyE_KMbTXKDRPBjigMfK/view?usp=sharing	4th year, Data Science, Warren	Los Angeles, CA	Reading, F1, TV shows	🍲 HaiDiLao, Corner Bakery Cafe, SomiSomi
9/19/2024 7:02:12	Matilda Gaddi	she/her	https://drive.google.com/file/d/1SCencJ5l57SYpl4RA2Y53mezoLX3Kcwt/view?usp=drive_link	3rd year, Data Science, Marshall	Boise, ID	My internship at the U.S. Department of Commerce, ultimate frisbee, friendship bracelets, Argentina	🫐 Blue Bowl, Fan-Fan, Trader Joe's
9/20/2024 0:51:06	Michelle Hong	she/her	https://drive.google.com/file/d/1I5S2U81eUyyzvbFOw9_Fro06U-1yf_ih/view?usp=sharing	2nd year, Data Science, Seventh	Dublin, CA	Bananagrams, thrifting, concerts	🐠 Hawaiian Fresh Seafood, Tacos El Gordo
9/19/2024 6:37:11	Minchan Kim	he/him	https://drive.google.com/file/d/1qpfrHjpjwGOPSnQmBbe1yFnCQAbntzqo/view?usp=sharing	3rd year, Data Science, Revelle	Seoul, South Korea	My internship at EY, Formula 1/cars, NBA, stocks/options trading	🍲 Tasty Pot, Woomiok, Marugame
9/20/2024 20:14:37	Pallavi Prabhu	she/her	https://drive.google.com/file/d/1ohZshbfRa9V2A-tACoXrtSYaCTc-oWX6/view?usp=sharing	4th year, Data Science, Marshall	Cypress, CA	Painting, crafting, tv shows	🍦 SomiSomi, Taco Stand
9/19/2024 8:23:18	Pranav Rajaram	he/him	https://dsc-courses.github.io/dsc10-2024-sp/assets/staff-images/sp24/rajaram-pranav.jpg	2nd year, Data Science, Marshall	Westford, MA	Football, poker, Drake	🥪 The Melt, Taco Stand, SomiSomi
9/19/2024 11:03:16	Raine Hoang	they/them	https://drive.google.com/file/d/1-Lxj8yY1REXiJym1caTnncbCFYi4O5RR/view?usp=sharing	3rd year, Data Science, Sixth	Los Angeles, CA	Drawing, crocheting, wood carving, video games	🍜 Marugame Udon, Haidilao 
9/20/2024 12:39:05	Sofia Tkachenko	she/her	https://drive.google.com/file/d/12_B5BDtQCgSzToeFfoygW_WedO_cx5sn/view?usp=drivesdk	3rd year, Applied Math, Muir	San Jose, CA	Hiking, hot springs, having sweet treats	🍲 Tofu House, Ben Gong Tea"""
lines = all_lines.split("\n")
for line in lines:
    write_markdown_file(line)
# Out:
# ../_staffers/muthu-aathi.md has been written successfully!
# ../_staffers/ho-ashley.md has been written successfully!
# ../_staffers/paraselli-athulith.md has been written successfully!
# ../_staffers/wang-bill.md has been written successfully!
# ../_staffers/gillet-charlie.md has been written successfully!
# ../_staffers/zhang-ciro.md has been written successfully!
# ../_staffers/wang-claire.md has been written successfully!
# ../_staffers/budidharma-daniel.md has been written successfully!
# ../_staffers/sehgal-dhruv.md has been written successfully!
# ../_staffers/chen-eric.md has been written successfully!
# ../_staffers/franco-francisco.md has been written successfully!
# ../_staffers/zheng-hargen.md has been written successfully!
# ../_staffers/determan-jack.md has been written successfully!
# ../_staffers/huynh-jason.md has been written successfully!
# ../_staffers/feng-kate.md has been written successfully!
# ../_staffers/nguyen-kathleen.md has been written successfully!
# ...

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/opt/python@3.11/bin/python3.11

# %%
import os
import re
import csv
import requests
from PIL import Image
from io import BytesIO

def download_and_save_images(csv_content, directory):
    # Create directory if it doesn't exist
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    # Parse the CSV content line by line
    reader = csv.reader(csv_content.splitlines())
    #next(reader)  # Skip the header row
    
    for row in reader:
        print(row)
        timestamp, full_name, pronouns, link = row[0].split("\t")
        first_name, last_name = full_name.split()
        
        # Format the file name
        file_name = f"{last_name.lower()}-{first_name.lower()}.jpg"
        file_path = os.path.join(directory, file_name)
        
        match = re.search(r'/d/([^/]+)/', link)
        if match:
            file_id = match.group(1)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        else:
            print(f"Failed to extract file ID from link for {full_name}. Skipping.")
            continue
        
        try:
            # Download the image using the modified download link
            response = requests.get(download_link)
            response.raise_for_status()
            
            # Open the image and convert it to JPEG if necessary
            img = Image.open(BytesIO(response.content))
            if img.format != 'JPEG':
                img = img.convert('RGB')
            
            # Save the image to the specified directory
            img.save(file_path, 'JPEG')
            print(f"Image for {full_name} has been saved successfully to {file_path}")
        
        except Exception as e:
            print(f"Failed to download and save image for {full_name}. Error: {e}")

# Copy-paste the first four columns from the staff onboarding form responses
csv_content = """9/19/2024 15:32:10	Aathi Muthu	he/him	https://drive.google.com/file/d/1Jta_xgahg1l4JvLQVaS9ME8fnARkjL-v/view?usp=sharing
9/19/2024 9:34:20	Ashley Ho	she/her	https://drive.google.com/file/d/1J1CjsEvzpwtIXh_9Qs13T-LgPu8vqxBJ/view?usp=drive_link
9/22/2024 21:35:09	Athulith Paraselli	he/him	https://drive.google.com/file/d/1ZLEx-0pdfsjVfIbvNqkDL43Z93G3KuCj/view?usp=drivesdk
9/22/2024 12:32:31	Bill Wang	he/him	https://drive.google.com/file/d/1SQNKL8hUxdpwIXB9cPNT6lqktqaWxhB8/view?usp=sharing
9/20/2024 16:31:43	Charlie Gillet	he/him	https://drive.google.com/file/d/1DTmypev9YYWUnpocoHmfv1IoXYV9E2iS/view?usp=drive_link
9/20/2024 18:55:41	Ciro Zhang	he/him	https://drive.google.com/file/d/1sw0lE791jZmE3fRRtuHlT9a8ibpZ2pWi/view?usp=sharing
9/19/2024 10:05:58	Claire Wang	she/her	https://drive.google.com/file/d/1wZ4u0cmXuRu_0hBRLYsTlsrttk-KGo2F/view?usp=sharing
9/20/2024 0:37:03	Daniel Budidharma	he/him	https://drive.google.com/file/d/1xwsVBFTvo6KaiobE2BEn9KSWhhn9SXnS/view?usp=sharing
9/19/2024 12:13:12	Dhruv Sehgal	he/him	https://drive.google.com/file/d/17EwLIyA9xByeJA_C6C8WDDvSSG09K-sg/view?usp=sharing
9/20/2024 21:43:04	Eric Chen	he/him	https://drive.google.com/file/d/1VcAgsnpBEIEFev2k3j1veITc4rWms4Jg/view?usp=sharing
9/19/2024 12:18:36	Francisco Franco 	he/him	https://drive.google.com/file/d/1b8m3p5FCeHMDM4RIcjWuR1kF0PdICzzL/view?usp=drive_link
9/19/2024 9:27:52	Hargen Zheng	he/him	https://drive.google.com/file/d/15_oMfo7QbNsFyTJaal0zxR_TgOZilwlk/view?usp=sharing
9/19/2024 9:56:37	Jack Determan	he/him	https://drive.google.com/file/d/1tEa2_-V4HhNu_TYwxwUQFg2AP-PXd2Um/view?usp=drive_link
9/19/2024 11:12:41	Jason Huynh	he/him	https://drive.google.com/file/d/1_wrHK-odM3sSvpySyulZcAGyc0jVN1eE/view?usp=sharing
9/19/2024 15:36:49	Kate Feng	she/her	https://drive.google.com/file/d/1j1t2dPwPL-AFVdFJJhJx9M1eNl2-xZHl/view?usp=sharing
9/19/2024 11:32:05	Kathleen Nguyen	she/her	https://drive.google.com/file/d/1SaO7j_5wPSYHVyE_KMbTXKDRPBjigMfK/view?usp=sharing
9/19/2024 7:02:12	Matilda Gaddi	she/her	https://drive.google.com/file/d/1SCencJ5l57SYpl4RA2Y53mezoLX3Kcwt/view?usp=drive_link
9/20/2024 0:51:06	Michelle Hong	she/her	https://drive.google.com/file/d/1I5S2U81eUyyzvbFOw9_Fro06U-1yf_ih/view?usp=sharing
9/19/2024 6:37:11	Minchan Kim	he/him	https://drive.google.com/file/d/1qpfrHjpjwGOPSnQmBbe1yFnCQAbntzqo/view?usp=sharing
9/20/2024 20:14:37	Pallavi Prabhu	she/her	https://drive.google.com/file/d/1ohZshbfRa9V2A-tACoXrtSYaCTc-oWX6/view?usp=sharing
9/19/2024 8:23:18	Pranav Rajaram	he/him	https://dsc-courses.github.io/dsc10-2024-sp/assets/staff-images/sp24/rajaram-pranav.jpg
9/19/2024 11:03:16	Raine Hoang	they/them	https://drive.google.com/file/d/1-Lxj8yY1REXiJym1caTnncbCFYi4O5RR/view?usp=sharing
9/20/2024 12:39:05	Sofia Tkachenko	she/her	https://drive.google.com/file/d/12_B5BDtQCgSzToeFfoygW_WedO_cx5sn/view?usp=drivesdk"""

# The directory where the images should be saved
directory = "../assets/staff-images/sp24"

# Call the function with the CSV content and the directory
download_and_save_images(csv_content, directory)

# This will extract some, others will need to be done manually.
# Out:
# ['9/19/2024 15:32:10\tAathi Muthu\the/him\thttps://drive.google.com/file/d/1Jta_xgahg1l4JvLQVaS9ME8fnARkjL-v/view?usp=sharing']
# Failed to download and save image for Aathi Muthu. Error: cannot identify image file <_io.BytesIO object at 0x1091e6c00>
# ['9/19/2024 9:34:20\tAshley Ho\tshe/her\thttps://drive.google.com/file/d/1J1CjsEvzpwtIXh_9Qs13T-LgPu8vqxBJ/view?usp=drive_link']
# Failed to download and save image for Ashley Ho. Error: cannot identify image file <_io.BytesIO object at 0x108af3330>
# ['9/22/2024 21:35:09\tAthulith Paraselli\the/him\thttps://drive.google.com/file/d/1ZLEx-0pdfsjVfIbvNqkDL43Z93G3KuCj/view?usp=drivesdk']
# Image for Athulith Paraselli has been saved successfully to ../assets/staff-images/sp24/paraselli-athulith.jpg
# ['9/22/2024 12:32:31\tBill Wang\the/him\thttps://drive.google.com/file/d/1SQNKL8hUxdpwIXB9cPNT6lqktqaWxhB8/view?usp=sharing']
# ...

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/opt/python@3.11/bin/python3.11
